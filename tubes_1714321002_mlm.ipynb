# %% [markdown]
# # 1. Mengimpor library yang dibutuhkan

# %%
import geopandas as gpd
import matplotlib as mp
import pandas as pd

from shapely.geometry import Point, Polygon
pd.options.display.max_rows = 15

# %% [markdown]
# # 2. Menambahkan / membaca data yang dibutuhkan

# %%
stasiun_sepeda = gpd.read_file("velib-disponibilite-en-temps-reel.geojson")
peta_paris = gpd.read_file('quartier_paris.shp')
jalan = gpd.read_file('voie.shp')

# %% [markdown]
# # 3. Menampilkan bentuk asli per dokumen

# %%
stasiun_sepeda.plot(figsize=(10,10))
# Out:
# <AxesSubplot:>

# %%
peta_paris.plot(figsize=(10,10))
# Out:
# <AxesSubplot:>

# %%
jalan.plot(figsize=(10,10))
# Out:
# <AxesSubplot:>

# %% [markdown]
# # 4. Melakukan Join 2 file menjadi satu

# %%
stations = gpd.sjoin(stasiun_sepeda, peta_paris[['l_qu', 'geometry']].copy(), op='within')
stations.head()
# Out:
#      ebike  capacity                           name  \
# 0        4        35  Benjamin Godard - Victor Hugo
# 257      4        38       Sablons - Georges Mandel
# 347      5        33         Jardin d'Acclimatation
# 363      2        18        Flandrin - Henri Martin
# 470      1        26                 Mahatma Gandhi
#
#     nom_arrondissement_communes  numbikesavailable  mechanical stationcode  \
# 0                         Paris                  7           3       16107
# 257                       Paris                 10           6       16108
# 347                       Paris                 13           8       16121
# 363                       Paris                  5           3       16018
# 470                       Paris                  3           2       16123
#
#     is_installed is_renting  numdocksavailable                    duedate  \
# 0            OUI        OUI                 28  2021-05-25T09:33:28+07:00
# 257          OUI        OUI                 28  2021-05-25T09:36:28+07:00
# 347          OUI        OUI                 19  2021-05-25T09:38:00+07:00
# 363          OUI        OUI                 13  2021-05-25T09:32:53+07:00
# 470          OUI        OUI                 23  2021-05-25T09:32:09+07:00
#
#     is_returning                  geometry  index_right            l_qu
# 0            OUI  POINT (2.27572 48.86598)           63  Porte-Dauphine
# 257          OUI  POINT (2.28189 48.86388)           63  Porte-Dauphine
# 347          OUI  POINT (2.27077 48.87877)           63  Porte-Dauphine
# 363          OUI  POINT (2.27242 48.86433)           63  Porte-Dauphine
# 470          OUI  POINT (2.26421 48.87636)           63  Porte-Dauphine

# %% [markdown]
# # 5. Menampilkan data sebaran titik penyewaan sepeda listrik di kota Paris

# %%
#ax = stations.plot(column='capacity', figsize=(15, 6), legend=True)
#ax.set(title = 'Sebaran titik penyewaan sepeda')
#ax.set_axis_off()

ax = peta_paris.plot(linewidth=0.5, color='#e8e2d3', figsize=(15, 7))
stations.plot(ax = ax, column='capacity', figsize=(15, 6), legend=True, legend_kwds={'label': "Kapasitas sepeda di titik penyewaan (per unit)"})
jalan.plot(ax = ax, figsize=(15, 6), color='orange', linewidth=0.5)

ax.set(title = 'Sebaran titik penyewaan sepeda listrik di Kota Paris');
ax.set_axis_off()
